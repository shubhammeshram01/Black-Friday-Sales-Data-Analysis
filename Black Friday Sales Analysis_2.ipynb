# %% [markdown]
# # Black Friday Sales Analysis :

# %% [markdown]
# #### This dataset comprises of sales transactions captured at a retail store. The dataset has 5,50,069 rows and 12 columns.

# %% [markdown]
# ## 1) Import libraries :

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2) Change the default values for displaying rows and columns

# %%
'''Displaying default maximum rows'''

pd.get_option("display.max_rows")
# Out:
# 60

# %%
'''Displaying default maximum columns'''

pd.get_option("display.max_columns")
# Out:
# 20

# %%
'''Set maximum row values'''

pd.set_option("display.max_rows" , 80)

# %%
'''Set maximum column values'''

pd.set_option("display.max_columns" , 30)

# %% [markdown]
# ## 3) Reset to the default values

# %%
pd.reset_option("display.max_rows")

pd.reset_option("display.max_columns")

# %% [markdown]
# ## 4) Upload dataset

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\Python Case Studies\blackfriday.csv")

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 5) Explore dataset

# %%
data.shape
# Out:
# (550068, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=550068, step=1)

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
data.count()
# Out:
# User_ID                       550068
# Product_ID                    550068
# Gender                        550068
# Age                           550068
# Occupation                    550068
# City_Category                 550068
# Stay_In_Current_City_Years    550068
# Marital_Status                550068
# Product_Category_1            550068
# Product_Category_2            376430
# Product_Category_3            166821
# Purchase                      550068
# dtype: int64

# %%
data.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# ## 6) Create new dataset having all the product related columns

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
'''Columns related to Products'''

[i for i in data.columns if "Product" in i]
# Out:
# ['Product_ID',
#  'Product_Category_1',
#  'Product_Category_2',
#  'Product_Category_3']

# %%
data[["Product_ID" , "Product_Category_1" , "Product_Category_2" , "Product_Category_3"]]
# Out:
#        Product_ID  Product_Category_1  Product_Category_2  Product_Category_3
# 0       P00069042                   3                 NaN                 NaN
# 1       P00248942                   1                 6.0                14.0
# 2       P00087842                  12                 NaN                 NaN
# 3       P00085442                  12                14.0                 NaN
# 4       P00285442                   8                 NaN                 NaN
# ...           ...                 ...                 ...                 ...
# 550063  P00372445                  20                 NaN                 NaN
# 550064  P00375436                  20                 NaN                 NaN
# 550065  P00375436                  20                 NaN                 NaN
# 550066  P00375436                  20                 NaN                 NaN
# 550067  P00371644                  20                 NaN                 NaN
#
# [550068 rows x 4 columns]

# %%
df_product = data[["Product_ID" , "Product_Category_1" , "Product_Category_2" , "Product_Category_3"]]

# %%
df_product
# Out:
#        Product_ID  Product_Category_1  Product_Category_2  Product_Category_3
# 0       P00069042                   3                 NaN                 NaN
# 1       P00248942                   1                 6.0                14.0
# 2       P00087842                  12                 NaN                 NaN
# 3       P00085442                  12                14.0                 NaN
# 4       P00285442                   8                 NaN                 NaN
# ...           ...                 ...                 ...                 ...
# 550063  P00372445                  20                 NaN                 NaN
# 550064  P00375436                  20                 NaN                 NaN
# 550065  P00375436                  20                 NaN                 NaN
# 550066  P00375436                  20                 NaN                 NaN
# 550067  P00371644                  20                 NaN                 NaN
#
# [550068 rows x 4 columns]

# %% [markdown]
# ## 7) Check the values

# %%
data.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
data["Gender"].values
# Out:
# array(['F', 'F', 'F', ..., 'F', 'F', 'F'], dtype=object)

# %%
data["Product_ID"].values
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00375436',
#        'P00375436', 'P00371644'], dtype=object)

# %% [markdown]
# ## 8) Check size

# %%
'''Size returns the number of elements underlying in dataset'''

data.size
# Out:
# 6600816

# %%
data.shape
# Out:
# (550068, 12)

# %%
data["Gender"].count()
# Out:
# 550068

# %%
data["Gender"].size
# Out:
# 550068

# %% [markdown]
# ## 9) Check all the columns and data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# ## 10) Change the data type of "Purchase" to "float"

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
data["Purchase"] = data["Purchase"].astype("float")

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %% [markdown]
# ## 11) Generate descriptive statistical values

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# ## 12) Use the same function on Categorical column

# %%
data.describe(include = "object")
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      550068  550068  550068        550068                     550068
# unique       3631       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq         1880  414259  219587        231173                     193821

# %% [markdown]
# ## 13) Get the percentage distribution of "Product_ID" available and highest occuring product in dataset

# %%
data["Product_ID"]
# Out:
# 0         P00069042
# 1         P00248942
# 2         P00087842
# 3         P00085442
# 4         P00285442
#             ...
# 550063    P00372445
# 550064    P00375436
# 550065    P00375436
# 550066    P00375436
# 550067    P00371644
# Name: Product_ID, Length: 550068, dtype: object

# %%
data["Product_ID"].value_counts()
# Out:
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: Product_ID, Length: 3631, dtype: int64

# %%
round(data["Product_ID"].value_counts(normalize = True)*100 , 2)
# Out:
# P00265242    0.34
# P00025442    0.29
# P00110742    0.29
# P00112142    0.28
# P00057642    0.27
#              ...
# P00314842    0.00
# P00298842    0.00
# P00231642    0.00
# P00204442    0.00
# P00066342    0.00
# Name: Product_ID, Length: 3631, dtype: float64

# %%
data["Product_ID"].value_counts().sort_values(ascending=False).head(5)
# Out:
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
# Name: Product_ID, dtype: int64

# %%
data["Product_ID"].value_counts().nlargest(5).plot(kind = "bar",color="skyblue",edgecolor="black")
# Out:
# <AxesSubplot:>

# %%
round(data["Product_ID"].value_counts(normalize = True)*100 ,2).sum()
# Out:
# 98.87

# %%
(data["Product_ID"].value_counts(normalize = True)*100).sum()
# Out:
# 100.0

# %% [markdown]
# ## 14) Check missing values

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data["Product_Category_2"]
# Out:
# 0          NaN
# 1          6.0
# 2          NaN
# 3         14.0
# 4          NaN
#           ...
# 550063     NaN
# 550064     NaN
# 550065     NaN
# 550066     NaN
# 550067     NaN
# Name: Product_Category_2, Length: 550068, dtype: float64

# %%
data["Product_Category_3"]
# Out:
# 0          NaN
# 1         14.0
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 550063     NaN
# 550064     NaN
# 550065     NaN
# 550066     NaN
# 550067     NaN
# Name: Product_Category_3, Length: 550068, dtype: float64

# %% [markdown]
# ## 15) Handling missing values

# %% [markdown]
# ### 1) Dropping column

# %%
temp = data.drop("Product_Category_3" , axis = 1 , inplace = False)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Purchase                    550068 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 46.2+ MB

# %%
temp.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Purchase                           0
# dtype: int64

# %% [markdown]
# ### 2) Dropping rows

# %%
temp[temp["Product_Category_2"].isna()].index
# Out:
# Int64Index([     0,      2,      4,      9,     11,     12,     21,     22,
#                 23,     26,
#             ...
#             550058, 550059, 550060, 550061, 550062, 550063, 550064, 550065,
#             550066, 550067],
#            dtype='int64', length=173638)

# %%
temp = temp.drop( temp[temp["Product_Category_2"].isna()].index , axis = 0 , inplace = False)

# %%
temp
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 545905  1006040  P00331042      M  26-35           6             B
# 545906  1006040  P00101942      M  26-35           6             B
# 545907  1006040  P00277642      M  26-35           6             B
# 545908  1006040  P00127642      M  26-35           6             B
# 545914  1006040  P00217442      M  26-35           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 376430 entries, 1 to 545914
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     376430 non-null  int64
#  1   Product_ID                  376430 non-null  object
#  2   Gender                      376430 non-null  object
#  3   Age                         376430 non-null  object
#  4   Occupation                  376430 non-null  int64
#  5   City_Category               376430 non-null  object
#  6   Stay_In_Current_City_Years  376430 non-null  object
#  7   Marital_Status              376430 non-null  int64
#  8   Product_Category_1          376430 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Purchase                    376430 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 34.5+ MB

# %%
temp.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# ## 16) Imputing missing values

# %% [markdown]
# ### 1) Impute with forward fill

# %%
data.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
data.fillna(method = "pad")
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data = data.fillna(method = "pad")

# %%
data.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            1
# Product_Category_3            1
# Purchase                      0
# dtype: int64

# %%
data[["Product_Category_2" , "Product_Category_3"]]
# Out:
#         Product_Category_2  Product_Category_3
# 0                      NaN                 NaN
# 1                      6.0                14.0
# 2                      6.0                14.0
# 3                     14.0                14.0
# 4                     14.0                14.0
# ...                    ...                 ...
# 550063                 2.0                11.0
# 550064                 2.0                11.0
# 550065                 2.0                11.0
# 550066                 2.0                11.0
# 550067                 2.0                11.0
#
# [550068 rows x 2 columns]

# %% [markdown]
# ### 2) Impute with backward fill

# %%
data.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
data.fillna(method = "bfill")
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data = data.fillna(method = "bfill")

# %%
data.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# ## 17) Indexing and Slicing

# %%
df = data.copy()
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.loc[0]
# Out:
# User_ID                         1000001
# Product_ID                    P00069042
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    3
# Product_Category_2                  6.0
# Product_Category_3                 14.0
# Purchase                         8370.0
# Name: 0, dtype: object

# %%
df.loc[0 , "Product_ID"]
# Out:
# 'P00069042'

# %%
df.loc[0:2 , ["Product_ID" , "Purchase"]]
# Out:
#   Product_ID  Purchase
# 0  P00069042    8370.0
# 1  P00248942   15200.0
# 2  P00087842    1422.0

# %%
df.loc[[0,2,4,5,8] , ["Age" , "Purchase"]]
# Out:
#      Age  Purchase
# 0   0-17    8370.0
# 2   0-17    1422.0
# 4    55+    7969.0
# 5  26-35   15227.0
# 8  46-50   15686.0

# %%
df.iloc[1]
# Out:
# User_ID                         1000001
# Product_ID                    P00248942
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    1
# Product_Category_2                  6.0
# Product_Category_3                 14.0
# Purchase                        15200.0
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# User_ID                         1006039
# Product_ID                    P00371644
# Gender                                F
# Age                               46-50
# Occupation                            0
# City_Category                         B
# Stay_In_Current_City_Years           4+
# Marital_Status                        1
# Product_Category_1                   20
# Product_Category_2                  2.0
# Product_Category_3                 11.0
# Purchase                          490.0
# Name: 550067, dtype: object

# %%
df.iloc[: , 0:4].head(5)
# Out:
#    User_ID Product_ID Gender   Age
# 0  1000001  P00069042      F  0-17
# 1  1000001  P00248942      F  0-17
# 2  1000001  P00087842      F  0-17
# 3  1000001  P00085442      F  0-17
# 4  1000002  P00285442      M   55+

# %% [markdown]
# ## 18) Fetch the rows having maximum purchase amount with complete row details

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
'''Maximum purchase value'''

df["Purchase"].max()
# Out:
# 23961.0

# %%
'''Index of maximum purchase value'''

df["Purchase"].idxmax()
# Out:
# 87440

# %%
df.iloc[87440]
# Out:
# User_ID                         1001474
# Product_ID                    P00052842
# Gender                                M
# Age                               26-35
# Occupation                            4
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        1
# Product_Category_1                   10
# Product_Category_2                 15.0
# Product_Category_3                  8.0
# Purchase                        23961.0
# Name: 87440, dtype: object

# %%
'''Get the rows with maximum purchase values'''


df[df["Purchase"] == 23961.0]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 87440   1001474  P00052842      M  26-35           4             A
# 93016   1002272  P00052842      M  26-35           0             C
# 370891  1003160  P00052842      M  26-35          17             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 87440                           2               1                  10
# 93016                           1               0                  10
# 370891                          3               0                  10
#
#         Product_Category_2  Product_Category_3  Purchase
# 87440                 15.0                 8.0   23961.0
# 93016                 15.0                 8.0   23961.0
# 370891                15.0                 8.0   23961.0

# %%
'''Get the index of maximum purchase values'''


df[df["Purchase"] == 23961.0].index
# Out:
# Int64Index([87440, 93016, 370891], dtype='int64')

# %% [markdown]
# ## 19) Get the purchase amount from 3rd row

# %%
'''at() is used for label based'''

df.at[3 , "Purchase"]
# Out:
# 1057.0

# %%
df.at[10 , "User_ID"]
# Out:
# 1000005

# %%
'''iat() is use for index based'''

df.iat[2 , 5]
# Out:
# 'A'

# %%
df.iat[5 , 10]
# Out:
# 14.0

# %% [markdown]
# ## 20) Find the purchase amount for user_id(1006039) and product_id(P00371644)

# %%
df[(df["User_ID"] == 1006039) & (df["Product_ID"] == "P00371644")]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550067                 2.0                11.0     490.0

# %%
df[(df["User_ID"] == 1006039) & (df["Product_ID"] == "P00371644")]["Purchase"]
# Out:
# 550067    490.0
# Name: Purchase, dtype: float64

# %%
df.loc[550067]
# Out:
# User_ID                         1006039
# Product_ID                    P00371644
# Gender                                F
# Age                               46-50
# Occupation                            0
# City_Category                         B
# Stay_In_Current_City_Years           4+
# Marital_Status                        1
# Product_Category_1                   20
# Product_Category_2                  2.0
# Product_Category_3                 11.0
# Purchase                          490.0
# Name: 550067, dtype: object

# %% [markdown]
# ## 21) Find the users those are in city 'A' with more than 4 years and purchase amount more than 10000

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df[(df["City_Category"] == "A") & (df["Stay_In_Current_City_Years"] > "4") & (df["Purchase"] > 10000)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 98      1000022  P00351142      M  18-25          15             A
# 100     1000022  P00195942      M  18-25          15             A
# 102     1000022   P0098242      M  18-25          15             A
# 103     1000022  P00262242      M  18-25          15             A
# 416     1000073  P00351142      M  18-25           4             A
# ...         ...        ...    ...    ...         ...           ...
# 545791  1006019  P00279442      M  26-35           0             A
# 545792  1006019  P00262342      M  26-35           0             A
# 545793  1006019  P00028842      M  26-35           0             A
# 545794  1006019  P00070342      M  26-35           0             A
# 545832  1006028   P0097242      M  18-25           4             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 98                             4+               0                   1
# ...

# %%
df[(df["City_Category"] == "A") & (df["Stay_In_Current_City_Years"] > "4") & (df["Purchase"] > 10000)].index
# Out:
# Int64Index([    98,    100,    102,    103,    416,    417,    419,    420,
#                870,   1612,
#             ...
#             544893, 544894, 545037, 545246, 545789, 545791, 545792, 545793,
#             545794, 545832],
#            dtype='int64', length=6947)

# %% [markdown]
# ## 22) Discard all the female users in city "B" with 3 years and purchase amount less than 1500

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df[(df["City_Category"] == "B") & (df["Stay_In_Current_City_Years"] == "3") & (df["Gender"] == "F") & (df["Purchase"] < 1500)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 80      1000018   P0094142      F  18-25           3             B
# 744     1000140  P00084642      F  36-45           1             B
# 774     1000146  P00112342      F  36-45          20             B
# 2001    1000319  P00083242      F  51-55           6             B
# 5586    1000899  P00101742      F  26-35           1             B
# ...         ...        ...    ...    ...         ...           ...
# 549774  1005618  P00370293      F  18-25           4             B
# 549785  1005635  P00370293      F  36-45           9             B
# 549826  1005687  P00370293      F   0-17           0             B
# 549866  1005752  P00375436      F    55+           0             B
# 549937  1005856  P00370293      F  26-35           7             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 80                              3               0                   4
# ...

# %%
df[~((df["City_Category"] == "B") & (df["Stay_In_Current_City_Years"] == "3") & (df["Gender"] == "F") & (df["Purchase"] < 1500))]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## 23) Find the records in dataset with below details

# %%
values = [1006038 , "P00375436" , "F" , "55+" ,1 , "C" , "2", 0 , 20 , 2.0 , 11.0 , 365 ]

df[df.isin(values)]
# Out:
#           User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0             NaN        NaN      F  NaN         NaN           NaN
# 1             NaN        NaN      F  NaN         NaN           NaN
# 2             NaN        NaN      F  NaN         NaN           NaN
# 3             NaN        NaN      F  NaN         NaN           NaN
# 4             NaN        NaN    NaN  55+         NaN             C
# ...           ...        ...    ...  ...         ...           ...
# 550063        NaN        NaN    NaN  NaN         NaN           NaN
# 550064        NaN  P00375436      F  NaN         1.0             C
# 550065        NaN  P00375436      F  NaN         NaN           NaN
# 550066  1006038.0  P00375436      F  55+         1.0             C
# 550067        NaN        NaN      F  NaN         0.0           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                 NaN
# ...

# %%
df[df.isin(values).all(axis = 1)]
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 550066  1006038  P00375436      F  55+           1             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550066                          2               0                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550066                 2.0                11.0     365.0

# %% [markdown]
# ## 24) Visualize everyting with occupation value 10 and mask everything left

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df[df["Occupation"] != 10]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
df.mask(df["Occupation"] != 10)
# Out:
#           User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001.0  P00069042      F  0-17        10.0             A
# 1       1000001.0  P00248942      F  0-17        10.0             A
# 2       1000001.0  P00087842      F  0-17        10.0             A
# 3       1000001.0  P00085442      F  0-17        10.0             A
# 4             NaN        NaN    NaN   NaN         NaN           NaN
# ...           ...        ...    ...   ...         ...           ...
# 550063        NaN        NaN    NaN   NaN         NaN           NaN
# 550064        NaN        NaN    NaN   NaN         NaN           NaN
# 550065        NaN        NaN    NaN   NaN         NaN           NaN
# 550066        NaN        NaN    NaN   NaN         NaN           NaN
# 550067        NaN        NaN    NaN   NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
mask_df = df.mask(df["Occupation"] != 10)

# %%
'''It will mask all the entries with NaN having occupation not equal to 10'''

mask_df
# Out:
#           User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001.0  P00069042      F  0-17        10.0             A
# 1       1000001.0  P00248942      F  0-17        10.0             A
# 2       1000001.0  P00087842      F  0-17        10.0             A
# 3       1000001.0  P00085442      F  0-17        10.0             A
# 4             NaN        NaN    NaN   NaN         NaN           NaN
# ...           ...        ...    ...   ...         ...           ...
# 550063        NaN        NaN    NaN   NaN         NaN           NaN
# 550064        NaN        NaN    NaN   NaN         NaN           NaN
# 550065        NaN        NaN    NaN   NaN         NaN           NaN
# 550066        NaN        NaN    NaN   NaN         NaN           NaN
# 550067        NaN        NaN    NaN   NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %% [markdown]
# ## 25) Sorting

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0

# %%
df.sort_index(ascending = False)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550067  1006039  P00371644      F  46-50           0             B
# 550066  1006038  P00375436      F    55+           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550063  1006033  P00372445      M  51-55          13             B
# ...         ...        ...    ...    ...         ...           ...
# 4       1000002  P00285442      M    55+          16             C
# 3       1000001  P00085442      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 0       1000001  P00069042      F   0-17          10             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550067                         4+               1                  20
# ...

# %%
df.sort_index(axis = 1)
# Out:
#           Age City_Category Gender  Marital_Status  Occupation  \
# 0        0-17             A      F               0          10
# 1        0-17             A      F               0          10
# 2        0-17             A      F               0          10
# 3        0-17             A      F               0          10
# 4         55+             C      M               0          16
# ...       ...           ...    ...             ...         ...
# 550063  51-55             B      M               1          13
# 550064  26-35             C      F               0           1
# 550065  26-35             B      F               1          15
# 550066    55+             C      F               0           1
# 550067  46-50             B      F               1           0
#
#         Product_Category_1  Product_Category_2  Product_Category_3 Product_ID  \
# 0                        3                 6.0                14.0  P00069042
# ...

# %%
df.sort_values("Purchase")["Purchase"]
# Out:
# 549221       12.0
# 549477       12.0
# 547819       12.0
# 548027       12.0
# 547538       12.0
#            ...
# 292083    23960.0
# 503697    23960.0
# 370891    23961.0
# 87440     23961.0
# 93016     23961.0
# Name: Purchase, Length: 550068, dtype: float64

# %%
df.sort_values("Purchase" , ascending = False)['Purchase']
# Out:
# 370891    23961.0
# 93016     23961.0
# 87440     23961.0
# 503697    23960.0
# 321782    23960.0
#            ...
# 546379       12.0
# 546185       12.0
# 547032       12.0
# 546181       12.0
# 549221       12.0
# Name: Purchase, Length: 550068, dtype: float64

# %% [markdown]
# ## 26) Find the top 20 most revenue generated customers and their purchased product ID

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0

# %%
df.sort_values(by = "Purchase" , ascending = False).head(20)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 370891  1003160  P00052842      M  26-35          17             C
# 93016   1002272  P00052842      M  26-35           0             C
# 87440   1001474  P00052842      M  26-35           4             A
# 503697  1005596  P00117642      M  36-45          12             B
# 321782  1001577  P00052842      M    55+           0             C
# 349658  1005848  P00119342      M  51-55          20             A
# 292083  1003045  P00052842      M  46-50           1             B
# 298378  1003947  P00116142      M  26-35           0             C
# 437804  1001387  P00086242      F  51-55          13             B
# 229329  1005367  P00085342      M  18-25           4             A
# 416883  1004117  P00161842      M  18-25           4             B
# 7542    1001178  P00116142      M    55+           0             C
# 373300  1003511  P00085342      M  51-55           0             C
# ...

# %%
df.sort_values(by = "Purchase" , ascending = False).iloc[:20 , :]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 370891  1003160  P00052842      M  26-35          17             C
# 93016   1002272  P00052842      M  26-35           0             C
# 87440   1001474  P00052842      M  26-35           4             A
# 503697  1005596  P00117642      M  36-45          12             B
# 321782  1001577  P00052842      M    55+           0             C
# 349658  1005848  P00119342      M  51-55          20             A
# 292083  1003045  P00052842      M  46-50           1             B
# 298378  1003947  P00116142      M  26-35           0             C
# 437804  1001387  P00086242      F  51-55          13             B
# 229329  1005367  P00085342      M  18-25           4             A
# 416883  1004117  P00161842      M  18-25           4             B
# 7542    1001178  P00116142      M    55+           0             C
# 373300  1003511  P00085342      M  51-55           0             C
# ...

# %%
top_20 = df.sort_values("Purchase" , ascending = False).head(20)

# %%
top_20["User_ID"].index
# Out:
# Int64Index([370891,  93016,  87440, 503697, 321782, 349658, 292083, 298378,
#             437804, 229329, 416883,   7542, 373300,  33268, 388010, 449656,
#             366333,  54364,  56879,  68926],
#            dtype='int64')

# %%
top_20["Product_ID"].value_counts()
# Out:
# P00052842    8
# P00085342    4
# P00116142    3
# P00086242    2
# P00117642    1
# P00119342    1
# P00161842    1
# Name: Product_ID, dtype: int64

# %% [markdown]
# ## 27) Find which age group is much active for purchasing products from website.

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %% [markdown]
# ## Replace gender "M" with "Male" and "F" with "Female"

# %%
df["Gender"] = df["Gender"].replace("M" , "Male")

df["Gender"] = df["Gender"].replace("F" , "Female")

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042  Female  0-17          10             A
# 1  1000001  P00248942  Female  0-17          10             A
# 2  1000001  P00087842  Female  0-17          10             A
# 3  1000001  P00085442  Female  0-17          10             A
# 4  1000002  P00285442    Male   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %% [markdown]
# ## 28) Generate the list of user_id with  corresponding age and find the total count of purchases that have done

# %%
df[["User_ID" , "Age"]].values.tolist()
# Out:
# [[1000001, '0-17'],
#  [1000001, '0-17'],
#  [1000001, '0-17'],
#  [1000001, '0-17'],
#  [1000002, '55+'],
#  [1000003, '26-35'],
#  [1000004, '46-50'],
#  [1000004, '46-50'],
#  [1000004, '46-50'],
#  [1000005, '26-35'],
#  [1000005, '26-35'],
#  [1000005, '26-35'],
#  [1000005, '26-35'],
#  [1000005, '26-35'],
#  [1000006, '51-55'],
#  [1000006, '51-55'],
#  [1000006, '51-55'],
#  [1000006, '51-55'],
#  [1000007, '36-45'],
#  [1000008, '26-35'],
#  [1000008, '26-35'],
#  [1000008, '26-35'],
#  [1000008, '26-35'],
#  [1000008, '26-35'],
#  [1000008, '26-35'],
#  [1000009, '26-35'],
#  [1000009, '26-35'],
#  [1000009, '26-35'],
#  [1000009, '26-35'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
#  [1000010, '36-45'],
# ...

# %%
df[["User_ID" , "Age"]].value_counts()
# Out:
# User_ID  Age
# 1001680  26-35    1026
# 1004277  36-45     979
# 1001941  36-45     898
# 1001181  36-45     862
# 1000889  46-50     823
#                   ...
# 1002111  55+         7
# 1005391  26-35       7
# 1002690  26-35       7
# 1005608  18-25       7
# 1000708  26-35       6
# Length: 5891, dtype: int64

# %% [markdown]
# ## 29) Get the different statistical values for purchase column

# %%
df["Purchase"].describe()
# Out:
# count    550068.000000
# mean       9263.968713
# std        5023.065394
# min          12.000000
# 25%        5823.000000
# 50%        8047.000000
# 75%       12054.000000
# max       23961.000000
# Name: Purchase, dtype: float64

# %% [markdown]
# ## 30) Find the total amount generated via website by selling products

# %%
import numpy as np

# %%
df["Purchase"].sum()
# Out:
# 5095812742.0

# %%
df["Purchase"].aggregate(np.sum)
# Out:
# 5095812742.0

# %%
df["Purchase"].aggregate([np.sum , np.mean ])
# Out:
# sum     5.095813e+09
# mean    9.263969e+03
# Name: Purchase, dtype: float64

# %% [markdown]
# ## 31) Find the mean for product 1 ,2 , 3

# %%
df[["Product_Category_1" , "Product_Category_2" , "Product_Category_3"]].aggregate(np.mean)
# Out:
# Product_Category_1     5.404270
# Product_Category_2     9.863190
# Product_Category_3    12.650723
# dtype: float64

# %% [markdown]
# ## 32) Tag records to "High Focused" transactions where purchase amount has been more than 5000. Remaining can be tagged as "general" transactions

# %%
df.head(2)
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042  Female  0-17          10             A
# 1  1000001  P00248942  Female  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0    8370.0
# 1                 6.0                14.0   15200.0

# %%
df["Category"] = df["Purchase"].apply(lambda x : "High Focused" if x>5000 else "General")

# %%
df
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042  Female   0-17          10             A
# 1       1000001  P00248942  Female   0-17          10             A
# 2       1000001  P00087842  Female   0-17          10             A
# 3       1000001  P00085442  Female   0-17          10             A
# 4       1000002  P00285442    Male    55+          16             C
# ...         ...        ...     ...    ...         ...           ...
# 550063  1006033  P00372445    Male  51-55          13             B
# 550064  1006035  P00375436  Female  26-35           1             C
# 550065  1006036  P00375436  Female  26-35          15             B
# 550066  1006038  P00375436  Female    55+           1             C
# 550067  1006039  P00371644  Female  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## 33) Based on gender, check the total purchased amount and average purchasing amount ?

# %%
df["Purchase"] = df['Purchase'].astype("int64")

# %%
df.groupby("Gender")["Purchase"].sum()
# Out:
# Gender
# Female    1186232642
# Male      3909580100
# Name: Purchase, dtype: int64

# %%
df.groupby("Gender")["Purchase"].mean()
# Out:
# Gender
# Female    8734.565765
# Male      9437.526040
# Name: Purchase, dtype: float64

# %%
df.groupby("Gender")["Purchase"].aggregate([np.sum , np.mean])
# Out:
#                sum         mean
# Gender
# Female  1186232642  8734.565765
# Male    3909580100  9437.526040
